# %% [markdown]
# # **Algoritmo apriori**
#
# En esta libreta exploraremos el modelo mercado canasta basado en el algoritmo apriori usando una base de datos de transacciones de una tienda de productos comestibles.

# %%
import pandas as pd

# %% [markdown]
# ## Carga de datos
# Primero leemos la base de datos [Online Retail II](https://archive.ics.uci.edu/ml/datasets/Online+Retail+II) de [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php) y mostramos algunos registros.

# %%
tdb_nan = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00502/online_retail_II.xlsx')
tdb_nan.head(5)
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# Eliminamos los registros inválidos y revisamos el número de registros.

# %%
print(tdb_nan.shape)
tdb = tdb_nan.dropna(axis=0)
print(tdb.shape)
# Out:
# (525461, 8)
# (417534, 8)

# %% [markdown]
# La base de datos cuenta con un registro por cada producto comprado (campo `Description`) y una factura asociada (`Invoice`), ademas de otros campos. Para nuestro ejercicio, vamos a utilizar únicamente `Invoice` y `Description`.

# %%
tdb = tdb[['Invoice', 'Description']]
tdb.head(5)
# Out:
#   Invoice                          Description
# 0  489434  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1  489434                   PINK CHERRY LIGHTS
# 2  489434                  WHITE CHERRY LIGHTS
# 3  489434         RECORD FRAME 7" SINGLE SIZE
# 4  489434       STRAWBERRY CERAMIC TRINKET BOX

# %% [markdown]
# Para encontrar elementos frecuentes, es necesario agrupar los productos comprados en una misma transacción usando el número de factura `Invoice`.

# %%
tdb = tdb.groupby(['Invoice'])['Description'].apply(set).reset_index(name='Description')
tdb.head(5)
# Out:
#   Invoice                                        Description
# 0  489434  {PINK DOUGHNUT TRINKET POT , 15CM CHRISTMAS GL...
# 1  489435  {HEART MEASURING SPOONS LARGE, LUNCHBOX WITH C...
# 2  489436  { PEACE WOODEN BLOCK LETTERS, FULL ENGLISH BRE...
# 3  489437  {RETRO COFFEE MUGS ASSORTED, WOODEN BOX ADVENT...
# 4  489438  {JUMBO BAG CHARLIE AND LOLA TOYS, JUMBO BAG TO...

# %% [markdown]
# Revisamos el número de transacciones totales en la base de datos.

# %%
d = len(set(e for t in tdb['Description'] for e in t))
n = len(tdb)

print('Número de elementos únicos: {0}\nNúmero de transacciones: {1}'.format(d, n))
# Out:
# Número de elementos únicos: 4459
# Número de transacciones: 23587

# %% [markdown]
# ## Ejercicio
# Programa el algoritmo Apriori y realiza la búsqueda de conjuntos con cardinalidad 1, 2 y 3 de elementos frecuentes usando diferentes soportes mínimos para las transacciones de la base de datos Online Retail II.

# %%
X = tdb.iloc[:200,:]
X
# Out:
#     Invoice                                        Description
# 0    489434  {PINK DOUGHNUT TRINKET POT , 15CM CHRISTMAS GL...
# 1    489435  {HEART MEASURING SPOONS LARGE, LUNCHBOX WITH C...
# 2    489436  { PEACE WOODEN BLOCK LETTERS, FULL ENGLISH BRE...
# 3    489437  {RETRO COFFEE MUGS ASSORTED, WOODEN BOX ADVENT...
# 4    489438  {JUMBO BAG CHARLIE AND LOLA TOYS, JUMBO BAG TO...
# ..      ...                                                ...
# 195  489876  {RETRO BLUE SPOTTY WASHING UP GLOVES, 12 MINI ...
# 196  489877  { WHITE CHERRY LIGHTS, HEART IVORY TRELLIS SMA...
# 197  489878  {VINTAGE BEAD NOTEBOOK, BEWARE OF THE CAT META...
# 198  489879  {SILVER SLEIGHBELL  WREATH, ENGLISH ROSE DESIG...
# 199  489880  {WHITE GOOSE FEATHER CHRISTMAS TREE , LUNCH BA...
#
# [200 rows x 2 columns]

# %%
def algoritmo_apriori(X,soporte_=0.5):
    #Definimos el soporte en y las variables auxiliares
    no_transacciones = X.shape[0]
    soporte = int(soporte_*no_transacciones//1 + 1)

    #PASOS PARA C1 Y F1

    #Creamos las variables y las variables auxiliares
    C1 = {}
    F1 = []

    #Guardamos los productos en un diccionario donde la llave son los productos y los valores son el número de transacciones en las que aparece
    for j in range(no_transacciones):
        for j1 in X.iloc[j,1]:
            if j1 in C1:
    
                C1[str(j1)] += 1

                #Cuando pasan el soporte se añaden a F1
                if C1[str(j1)] > soporte and not (str(j1) in F1):
                    F1.append(str(j1)) 
            else:
                C1[str(j1)] = 1

    print('El conjunto F1 es ',F1)    
    print('El tamaño del conjunto F1 es ',len(F1))

    #PASOS PARA C2 Y F2

    #Creamos las variables y las variables auxiliares
    C2 = {}
    F2_ = {}
    F2 = []

    #Se toman los valores de F1 y posteriormente se meten todas las combinaciones sin repetir a C2
    for k in range(len(F1)-1):
        for k1 in range(k,len(F1)):
            j = F1[k]
            j1 = F1[k1]
            if j != j1:
                if not ((j,j1) in C2) and not ((j1,j) in C2):
                    C2[(j,j1)] = 0

    #Se usa como variable auxiliar F2_ para contar el número de veces que aparecen cada tupla en la misma transacción
    for j,v in C2.keys():
        for j1 in range(no_transacciones):
            a_ = X.iloc[j1,1]
            if j in a_ and v in a_:
                if (j,v) in F2_:
                    F2_[(j,v)] += 1
                else:
                    F2_[(j,v)] = 1

    #Con el cuenta hecha en F2_ se guardan los valores en F2 que pasaron el umbral
    for j,v in F2_.items():
        if v > soporte:
            F2.append(j)


    print('El conjunto F2 es ',F2)
    print('El tamaño del conjunto F2 es ',len(F2))

    #PASOS PARA V3 Y F3

    #Creamos las variables y las variables auxiliares
    C3 = {}
    F3_ = {}
    F3 = []

    #Se toman los pares que estan en F2 y se proceden a añadir tripletas con el uso de estos valores tomando en cuenta la cerradura y se añaden a C3
    for k1 in range(len(F2)-1):
        for k2  in range(k1+1,len(F2)):
            j1 = F2[k1]
            j2 = F2[k2]

            #Se revisa si dos tuplas comparten un elemento en común y además si son distintas, si los valores que no son iguales se
            #aparece como par en F2 entonces podemos hacer la unirlos manteniendo la cerradura
            if (j1[0] in j2 or j1[1] in j2) and j1 != j2:


                #Casos como pueden venir acomodados estos valores
                if j1[0] == j2[0]:
                    if (j1[1],j2[1]) in F2 or (j2[1],j1[1]) in F2:
                        A = [j1[0],j1[1],j2[1]]
                        A = tuple(sorted(A))
                        C3[A] = 0

                elif j1[0] == j2[1]:
                    if (j1[1],j2[0]) in F2 or (j2[0],j1[1]) in F2:
                        A = [j1[0],j1[1],j2[0]]
                        A = tuple(sorted(A))
                        C3[A] = 0
                            

                elif j1[1] == j2[0]:
                    if (j1[0],j2[1]) in F2 or (j2[1],j1[0]) in F2:
                        A = [j1[0],j1[1],j2[1]]
                        A = tuple(sorted(A))
                        C3[A] = 0

                elif j1[1] == j2[1]:
                    if (j1[0],j2[0]) in F2 or (j2[0],j1[0]) in F2:
                        A = [j1[0],j1[1],j2[0]]
                        A = tuple(sorted(A))
                        C3[A] = 0

    #Contamos el número de veces que aparecen las tripletas en la misma transacción y guardamos la información con ayuda de F3_
    for j,v,k in C3.keys():
        for j1 in range(no_transacciones):
            a_ = X.iloc[j1,1]
            if j in a_ and v in a_ and k in a_:
                b_ = tuple(sorted([j,v,k]))
                if b_ in F2_:
                    F3_[b_] += 1
                else:
                    F3_[b_] = 1

    #Guardamos en F3 todas las tripletas que pasaron el umbral
    for j,v in F3_.items():
        if v > soporte:
            F3.append(j)

    print('El conjunto F3 es ',F3)
    print('El tamaño del conjunto F3 es ',len(F3))

# %%
algoritmo_apriori(X,0.04)
# Out:
# El conjunto F1 es  ["PAPER CHAIN KIT 50'S CHRISTMAS ", 'SCOTTIE DOG HOT WATER BOTTLE', 'ANTIQUE SILVER TEA GLASS ETCHED', 'BAKING SET 9 PIECE RETROSPOT ', 'WHITE HANGING HEART T-LIGHT HOLDER', 'GREY HEART HOT WATER BOTTLE', 'RETRO SPOT TEA SET CERAMIC 11 PC ', 'UNION JACK HOT WATER BOTTLE ', 'STRAWBERRY CERAMIC TRINKET BOX', 'JUMBO BAG RED WHITE SPOTTY ', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'RED SPOTTY COIR DOORMAT', 'ASSORTED COLOUR BIRD ORNAMENT', ' WHITE CHERRY LIGHTS', 'PACK OF 72 RETRO SPOT CAKE CASES', 'PLEASE ONE PERSON  METAL SIGN', 'RED SPOTTY CUP', 'SWEETHEART CERAMIC TRINKET BOX', 'RED SPOT HEART HOT WATER BOTTLE', 'PAPER CHAIN KIT RETRO SPOT', "SET OF THREE 50'S GIFT WRAPS ", 'RED/WHITE DOTS RUFFLED UMBRELLA', 'REX CASH+CARRY JUMBO SHOPPER', 'RETRO SPOT TRADITIONAL TEAPOT ', 'JUMBO STORAGE BAG SUKI', 'WHITE SKULL HOT WATER BOTTLE ', 'CHOCOLATE HOT WATER BOTTLE', 'FAIRY CAKE CANDLES', 'SET OF THREE VINTAGE GIFT WRAPS', ' VINTAGE DESIGN GIFT TAGS', 'HOME BUILDING BLOCK WORD', 'FELTCRAFT DOLL MOLLY', '60 TEATIME FAIRY CAKE CASES', 'PARTY CONE CHRISTMAS DECORATION ', 'RED HANGING HEART T-LIGHT HOLDER', 'POPCORN HOLDER , SMALL ', 'CREAM HEART CARD HOLDER', 'HEART FILIGREE DOVE  SMALL', 'LOVE BUILDING BLOCK WORD', 'JUMBO BAG PINK VINTAGE PAISLEY', 'SET/20 RED SPOTTY PAPER NAPKINS ', 'RED SPOTTY ROUND CAKE TINS', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'RED WOOLLY HOTTIE WHITE HEART.', "PINK FAIRY CAKE CHILD'S APRON", 'RED SPOTTY CHARLOTTE BAG', 'CHARLOTTE BAG , PINK/WHITE SPOTS', 'LUNCH BAG RED SPOTTY', '200 RED + WHITE BENDY STRAWS', 'CHICK GREY HOT WATER BOTTLE', 'UNION JACK FLAG PASSPORT COVER ']
# El tamaño del conjunto F1 es  52
# El conjunto F2 es  [("PAPER CHAIN KIT 50'S CHRISTMAS ", 'PAPER CHAIN KIT RETRO SPOT'), ('STRAWBERRY CERAMIC TRINKET BOX', 'SWEETHEART CERAMIC TRINKET BOX')]
# El tamaño del conjunto F2 es  2
# El conjunto F3 es  []
# El tamaño del conjunto F3 es  0

# %%
algoritmo_apriori(X,0.01)
# Out:
# El conjunto F1 es  ['SCOTTIE DOG HOT WATER BOTTLE', 'BAKING SET 9 PIECE RETROSPOT ', 'UNION JACK HOT WATER BOTTLE ', 'RETRO RED SPOTTY WASHING UP GLOVES', 'WHITE HANGING HEART T-LIGHT HOLDER', 'PARTY CONE CHRISTMAS DECORATION ', "PAPER CHAIN KIT 50'S CHRISTMAS ", 'PLEASE ONE PERSON  METAL SIGN', ' WHITE CHERRY LIGHTS', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'ASSORTED COLOUR BIRD ORNAMENT', 'POSTAGE', 'VINTAGE SNAKES & LADDERS', 'SET OF THREE VINTAGE GIFT WRAPS', 'PAPER CHAIN KIT RETRO SPOT', 'ANTIQUE SILVER TEA GLASS ETCHED', 'COFFEE MUG DOG + BALL DESIGN', 'RETRO SPOT TEA SET CERAMIC 11 PC ', 'PINK BLUE FELT CRAFT TRINKET BOX', 'STRAWBERRY CERAMIC TRINKET BOX', 'VINTAGE HEADS AND TAILS CARD GAME ', 'RED HANGING HEART T-LIGHT HOLDER', 'CHARLIE+LOLA PINK HOT WATER BOTTLE', 'HOME BUILDING BLOCK WORD', 'DOOR MAT TOPIARY', 'RED SPOT HEART HOT WATER BOTTLE', 'SWEETHEART CERAMIC TRINKET BOX', ' VINTAGE DESIGN GIFT TAGS', 'JUMBO BAG RED WHITE SPOTTY ', 'KINGS CHOICE CIGAR BOX MATCHES ', 'FANCY FONT HOME SWEET HOME DOORMAT', 'FELTCRAFT DOLL MARIA', 'FELTCRAFT DOLL MOLLY', 'WHITE SKULL HOT WATER BOTTLE ', 'PINK 3 PIECE MINI DOTS CUTLERY SET', 'VINTAGE CREAM 3 BASKET CAKE STAND', "SET OF THREE 50'S GIFT WRAPS ", 'PINK STRIPE HOT WATER BOTTLE', 'PINK CREAM FELT CRAFT TRINKET BOX ', 'PACK OF 72 RETRO SPOT CAKE CASES', 'RED SPOTTY COIR DOORMAT', 'RED TOADSTOOL LED NIGHT LIGHT', 'REX CASH+CARRY JUMBO SHOPPER', 'GREY HEART HOT WATER BOTTLE', 'JUMBO BAG PINK VINTAGE PAISLEY', 'CHRISTMAS CRAFT HEART DECORATIONS', 'LOVE BUILDING BLOCK WORD', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'ANTIQUE LILY FAIRY LIGHTS', 'LADIES & GENTLEMEN METAL SIGN', 'HEART FILIGREE DOVE  SMALL', 'CHICK GREY HOT WATER BOTTLE', 'COSY HOUR GIANT TUBE MATCHES', 'FELTCRAFT DOLL ROSIE', '12 PENCILS SMALL TUBE RED SPOTTY', 'ZINC METAL HEART DECORATION', 'CHRISTMAS CRAFT WHITE FAIRY ', 'DOOR MAT NEW ENGLAND', 'POPCORN HOLDER , SMALL ', 'RED 3 PIECE MINI DOTS CUTLERY SET', 'BINGO SET', 'BLUE 3 PIECE MINI DOTS CUTLERY SET', 'POTTING SHED TEA MUG', 'FAWN BLUE HOT WATER BOTTLE', 'PINK/BROWN DOTS RUFFLED UMBRELLA', 'KINGS CHOICE MUG', 'BLUE/BROWN DOTS RUFFLED UMBRELLA', 'DOOR MAT FAIRY CAKE', 'RED/WHITE DOTS RUFFLED UMBRELLA', 'BLACK/BLUE DOTS RUFFLED UMBRELLA', 'PINK DOUGHNUT TRINKET POT ', 'GREEN 3 PIECE MINI DOTS CUTLERY SET', 'MUSHROOM BLUE HOT WATER BOTTLE', "PINK FAIRY CAKE CHILD'S APRON", 'WHITE TISSUE REAM', '60 TEATIME FAIRY CAKE CASES', 'SMALLFOLKART BAUBLE CHRISTMAS DEC', 'WOODEN BOX ADVENT CALENDAR ', 'HEART IVORY TRELLIS LARGE', 'SET/10 PINK SPOTTY PARTY CANDLES', 'BLUE SPOTTY BOWL', 'RED SPOTTY CUP', 'RED SPOTTY ROUND CAKE TINS', 'FAIRY CAKE CANDLES', '15CM CHRISTMAS GLASS BALL 20 LIGHTS', 'PAINTED BIRD ASSORTED CHRISTMAS', 'DOORMAT HEARTS', 'HEART FILIGREE DOVE LARGE', 'BATH BUILDING BLOCK WORD', 'RED STAR CARD HOLDER', 'DOG BOWL , CHASING BALL DESIGN', 'CHOCOLATE HOT WATER BOTTLE', 'VINTAGE SNAP CARDS', 'RED SPOTTY BOWL', 'JUMBO  BAG BAROQUE BLACK WHITE', 'RIBBON REEL STRIPES DESIGN ', 'FROSTED BOX 9 WHITE T-LIGHT CANDLES', 'WOODEN PICTURE FRAME WHITE FINISH', 'HANGING HEART ZINC T-LIGHT HOLDER', 'CREAM HEART CARD HOLDER', 'RED SPOT CERAMIC DRAWER KNOB', 'SET/10 BLUE SPOTTY PARTY CANDLES', 'RETRO SPOT LAMP', 'JUMBO BAG SCANDINAVIAN PAISLEY', 'BIRD DECORATION RED SPOT', 'JUMBO BAG TOYS ', 'JUMBO STORAGE BAG SUKI', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'CHARLOTTE BAG , PINK/WHITE SPOTS', 'LUNCH BAG RED SPOTTY', 'CHARLIE + LOLA RED HOT WATER BOTTLE', 'RETRO SPOT MUG', 'RED SPOTTY CHILDS UMBRELLA', 'PREMIUM CHURCH CANDLE', 'DOOR MAT 3 SMILEY CATS', 'LUNCH BAG WOODLAND', 'TEA TIME CAKE STAND IN GIFT BOX', 'RED SPOTTY CHILDS APRON', 'WOODLAND CHARLOTTE BAG', 'PINK SPOTTY BOWL', 'RED SPOTTY CHARLOTTE BAG', 'RED WOOLLY HOTTIE WHITE HEART.', 'RED SPOTTY OVEN GLOVE DOUBLE', 'COSY HOUR CIGAR BOX MATCHES ', 'WOODEN FRAME ANTIQUE WHITE ', 'VINTAGE UNION JACK BUNTING', 'DOOR MAT WELCOME PUPPIES', 'UNION JACK GUNS & ROSES  DOORMAT', 'HAND OVER THE CHOCOLATE   SIGN ', 'CHRISTMAS PUDDING ...
# El tamaño del conjunto F1 es  350
# El conjunto F2 es  [('SCOTTIE DOG HOT WATER BOTTLE', 'BAKING SET 9 PIECE RETROSPOT '), ('SCOTTIE DOG HOT WATER BOTTLE', 'UNION JACK HOT WATER BOTTLE '), ('SCOTTIE DOG HOT WATER BOTTLE', "PAPER CHAIN KIT 50'S CHRISTMAS "), ('SCOTTIE DOG HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY'), ('SCOTTIE DOG HOT WATER BOTTLE', 'ASSORTED COLOUR BIRD ORNAMENT'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RETRO SPOT TEA SET CERAMIC 11 PC '), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOT HEART HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'JUMBO BAG RED WHITE SPOTTY '), ('SCOTTIE DOG HOT WATER BOTTLE', 'KINGS CHOICE CIGAR BOX MATCHES '), ('SCOTTIE DOG HOT WATER BOTTLE', 'FELTCRAFT DOLL MARIA'), ('SCOTTIE DOG HOT WATER BOTTLE', 'WHITE SKULL HOT WATER BOTTLE '), ('SCOTTIE DOG HOT WATER BOTTLE', 'PACK OF 72 RETRO SPOT CAKE CASES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'REX CASH+CARRY JUMBO SHOPPER'), ('SCOTTIE DOG HOT WATER BOTTLE', 'GREY HEART HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'FELTCRAFT DOLL ROSIE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOTTY CUP'), ('SCOTTIE DOG HOT WATER BOTTLE', 'FAIRY CAKE CANDLES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CHOCOLATE HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CHARLOTTE BAG , PINK/WHITE SPOTS'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOTTY CHARLOTTE BAG'), ('SCOTTIE DOG HOT WATER BOTTLE', 'VINTAGE UNION JACK BUNTING'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RETRO SPOT TRADITIONAL TEAPOT '), ('SCOTTIE DOG HOT WATER BOTTLE', 'SET/20 RED SPOTTY PAPER NAPKINS '), ('SCOTTIE DOG HOT WATER BOTTLE', 'KNITTED UNION FLAG HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'SET/3 RED GINGHAM ROSE STORAGE BOX'), ('BAKING SET 9 PIECE RETROSPOT ', 'UNION JACK HOT WATER BOTTLE '), ('BAKING SET 9 PIECE RETROSPOT ', "PAPER CHAIN KIT 50'S CHRISTMAS "), ('BAKING SET 9 PIECE RETROSPOT ', 'SET OF THREE VINTAGE GIFT WRAPS'), ('BAKING SET 9 PIECE RETROSPOT ', 'RETRO SPOT TEA SET CERAMIC 11 PC '), ('BAKING SET 9 PIECE RETROSPOT ', 'RED SPOT HEART HOT WATER BOTTLE'), ('BAKING SET 9 PIECE RETROSPOT ', ' VINTAGE DESIGN GIFT TAGS'), ('BAKING SET 9 PIECE RETROSPOT ', 'JUMBO BAG RED WHITE SPOTTY '), ('BAKING SET 9 PIECE RETROSPOT ', 'FELTCRAFT DOLL MOLLY'), ('BAKING SET 9 PIECE RETROSPOT ', 'WHITE SKULL HOT WATER BOTTLE '), ('BAKING SET 9 PIECE RETROSPOT ', 'PACK OF 72 RETRO SPOT CAKE CASES'), ('BAKING SET 9 PIECE RETROSPOT ', 'RED TOADSTOOL LED NIGHT LIGHT'), ('BAKING SET 9 PIECE RETROSPOT ', 'JUMBO BAG PINK VINTAGE PAISLEY'), ('BAKING SET 9 PIECE RETROSPOT ', 'RED/WHITE DOTS RUFFLED UMBRELLA'), ('BAKING SET 9 PIECE RETROSPOT ', '60 TEATIME FAIRY CAKE CASES'), ('BAKING SET 9 PIECE RETROSPOT ', 'BIRD DECORATION RED SPOT'), ('BAKING SET 9 PIECE RETROSPOT ', 'RED SPOTTY CHARLOTTE BAG'), ('BAKING SET 9 PIECE RETROSPOT ', 'RETRO SPOT TRADITIONAL TEAPOT '), ('BAKING SET 9 PIECE RETROSPOT ', 'SET/20 RED SPOTTY PAPER NAPKINS '), ('BAKING SET 9 PIECE RETROSPOT ', 'RETRO SPOT CAKE STAND'), ('UNION JACK HOT WATER BOTTLE ', 'WHITE HANGING HEART T-LIGHT HOLDER'), ('UNION JACK HOT WATER BOTTLE ', "PAPER CHAIN KIT 50'S CHRISTMAS "), ('UNION JACK HOT WATER BOTTLE ', 'PLEASE ONE PERSON  METAL SIGN'), ('UNION JACK HOT WATER BOTTLE ', 'HOT WATER BOTTLE TEA AND SYMPATHY'), ('UNION JACK HOT WATER BOTTLE ', 'RED HANGING HEART T-LIGHT HOLDER'), ('UNION JACK HOT WATER BOTTLE ', 'SWEETHEART CERAMIC TRINKET BOX'), ('UNION JACK HOT WATER BOTTLE ', 'WHITE SKULL HOT WATER BOTTLE '), ('UNION JACK HOT WATER BOTTLE ', 'RED SPOTTY COIR DOORMAT'), ('UNION JACK HOT WATER BOTTLE ', 'FAWN BLUE HOT WATER BOTTLE'), ('UNION JACK HOT WATER BOTTLE ', 'MUSHROOM BLUE HOT WATER BOTTLE'), ('UNION JACK HOT WATER BOTTLE ', 'RED SPOTTY ROUND CAKE TINS'), ('UNION JACK HOT WATER BOTTLE ', 'CHOCOLATE HOT WATER BOTTLE'), ('UNION JACK HOT WATER BOTTLE ', 'RETRO SPOT TRADITIONAL TEAPOT '), ('UNION JACK HOT WATER BOTTLE ', 'PINK HEART DOTS HOT WATER BOTTLE'), ('UNION JACK HOT WATER BOTTLE ', 'VINTAGE UNION JACK CUSHION COVER'), ('RETRO RED SPOTTY WASHING UP GLOVES', 'WH ...
# El tamaño del conjunto F2 es  356
# El conjunto F3 es  []
# El tamaño del conjunto F3 es  0

# %%
algoritmo_apriori(X,0.005)
# Out:
# El conjunto F1 es  ['SCOTTIE DOG HOT WATER BOTTLE', 'BAKING SET 9 PIECE RETROSPOT ', 'PARTY CONE CHRISTMAS DECORATION ', 'POSTAGE', 'RETRO RED SPOTTY WASHING UP GLOVES', 'UNION JACK HOT WATER BOTTLE ', 'WHITE HANGING HEART T-LIGHT HOLDER', "PAPER CHAIN KIT 50'S CHRISTMAS ", 'RETRO SPOT TEA SET CERAMIC 11 PC ', 'JUMBO BAG PINK VINTAGE PAISLEY', 'CHARLIE+LOLA PINK HOT WATER BOTTLE', 'PINK BLUE FELT CRAFT TRINKET BOX', 'PLEASE ONE PERSON  METAL SIGN', 'VINTAGE SNAKES & LADDERS', ' WHITE CHERRY LIGHTS', 'SET OF THREE VINTAGE GIFT WRAPS', 'PAPER CHAIN KIT RETRO SPOT', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'PAINTED BIRD ASSORTED CHRISTMAS', 'AREA PATROLLED METAL SIGN', 'ASSORTED COLOUR BIRD ORNAMENT', 'LADIES & GENTLEMEN METAL SIGN', 'ANTIQUE SILVER TEA GLASS ETCHED', 'RED TOADSTOOL LED NIGHT LIGHT', 'BIRD DECORATION RED SPOT', 'RED HANGING HEART T-LIGHT HOLDER', 'RETRO SPOT LAMP', 'COFFEE MUG DOG + BALL DESIGN', 'ANTIQUE LILY FAIRY LIGHTS', 'KINGS CHOICE SMALL TUBE MATCHES', 'CHOCOLATE HOT WATER BOTTLE', 'KINGS CHOICE CIGAR BOX MATCHES ', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'RED SPOT HEART HOT WATER BOTTLE', '6 RIBBONS RUSTIC CHARM', 'HOME BUILDING BLOCK WORD', 'HANGING HEART ZINC T-LIGHT HOLDER', 'LOVE BUILDING BLOCK WORD', 'ZINC METAL HEART DECORATION', 'STRAWBERRY CERAMIC TRINKET BOX', 'RED SPOTTY BOWL', 'JUMBO BAG RED WHITE SPOTTY ', 'PINK DOUGHNUT TRINKET POT ', 'UNION JACK FLAG PASSPORT COVER ', 'VINTAGE HEADS AND TAILS CARD GAME ', ' VINTAGE DESIGN GIFT TAGS', 'BLUE SPOTTY BOWL', 'DOOR MAT TOPIARY', 'BLUE WHITE SCARF HOT WATER BOTTLE', 'SWEETHEART CERAMIC TRINKET BOX', 'CHARLIE + LOLA RED HOT WATER BOTTLE', 'FANCY FONT HOME SWEET HOME DOORMAT', 'BINGO SET', 'WHITE SKULL HOT WATER BOTTLE ', 'PINK CREAM FELT CRAFT TRINKET BOX ', 'VINTAGE SNAP CARDS', 'RED SPOTTY COIR DOORMAT', 'PINK CHERRY LIGHTS', 'RED SPOT CERAMIC DRAWER KNOB', 'FELTCRAFT DOLL MARIA', 'FELTCRAFT DOLL MOLLY', 'POPCORN HOLDER , SMALL ', 'FELTCRAFT DOLL EMILY', 'PINK STRIPE HOT WATER BOTTLE', 'SET/10 PINK SPOTTY PARTY CANDLES', 'GREY HEART HOT WATER BOTTLE', 'DOORMAT HEARTS', 'CHICK GREY HOT WATER BOTTLE', 'DOOR MAT FAIRY CAKE', 'PACK OF 72 RETRO SPOT CAKE CASES', 'PINK 3 PIECE MINI DOTS CUTLERY SET', 'COSY HOUR GIANT TUBE MATCHES', 'CHARLOTTE BAG , PINK/WHITE SPOTS', 'SAVE THE PLANET MUG', 'VINTAGE CREAM 3 BASKET CAKE STAND', '60 TEATIME FAIRY CAKE CASES', 'WOODEN BOX ADVENT CALENDAR ', 'GREEN 3 PIECE MINI DOTS CUTLERY SET', "SET OF THREE 50'S GIFT WRAPS ", 'RED 3 PIECE MINI DOTS CUTLERY SET', 'TOXIC AREA  DOOR HANGER ', 'FELTCRAFT DOLL ROSIE', 'BLUE 3 PIECE MINI DOTS CUTLERY SET', 'FAWN BLUE HOT WATER BOTTLE', 'HAND OVER THE CHOCOLATE   SIGN ', 'ROSE DU SUD CHILDS APRON', 'LARGE HEART MEASURING SPOONS', 'KINGS CHOICE MUG', 'CINAMMON SET OF 9 T-LIGHTS', 'CHRISTMAS CRAFT HEART DECORATIONS', '12 PENCILS SMALL TUBE RED SPOTTY', 'DOOR MAT NEW ENGLAND', 'SET OF MEADOW  FLOWER STICKERS', 'RED SPOTTY ROUND CAKE TINS', 'WOOD S/3 CABINET ANT WHITE FINISH', 'JUMBO BAG TOYS ', 'WOODLAND CHARLOTTE BAG', 'RED SPOTTY CUP', 'LUNCHBOX WITH CUTLERY FAIRY CAKES ', 'BATH BUILDING BLOCK WORD', 'DOG BOWL , CHASING BALL DESIGN', 'REX CASH+CARRY JUMBO SHOPPER', 'HEART FILIGREE DOVE  SMALL', 'S/6 WOODEN SKITTLES IN COTTON BAG', 'WASH BAG VINTAGE ROSE PAISLEY', 'ASSTD DESIGN BUBBLE GUM RING', 'SMALLFOLKART BAUBLE CHRISTMAS DEC', 'CHRISTMAS CRAFT WHITE FAIRY ', "PINK FAIRY CAKE CHILD'S APRON", 'CHOCOLATE THIS WAY METAL SIGN', 'RED WOOLLY HOTTIE WHITE HEART.', 'DOOR MAT GREEN PAISLEY ', 'WHITE CHRISTMAS TREE DECORATION ', 'STAR DECORATION RUSTIC', 'ANGEL DECORATION 3 BUTTONS ', 'POTTING SHED TEA MUG', 'HEART IVORY TRELLIS LARGE', 'CREAM HEART CARD HOLDER', 'GREY FLORAL FELTCRAFT SHOULDER BAG', 'SET OF 6 CAKE CHOPSTICKS', 'PINK/BROWN DOTS RUFFLED UMBRELLA', 'BLUE/BROWN DOTS RUFFLED UMBRELLA', 'WOODEN FRAME ANTIQUE WHITE ', 'VICTORIAN GLASS HANGING T-LIGHT', 'PACK OF 12 RED SPOTTY TISSUES ', 'RIBBON REEL STRIPES DESIGN ', 'RIBBON REEL HEARTS DESIGN ', 'RED/WHITE DOTS RUFFLED UMBRELLA', ' ...
# El tamaño del conjunto F1 es  508
# El conjunto F2 es  [('SCOTTIE DOG HOT WATER BOTTLE', 'BAKING SET 9 PIECE RETROSPOT '), ('SCOTTIE DOG HOT WATER BOTTLE', 'PARTY CONE CHRISTMAS DECORATION '), ('SCOTTIE DOG HOT WATER BOTTLE', 'UNION JACK HOT WATER BOTTLE '), ('SCOTTIE DOG HOT WATER BOTTLE', 'WHITE HANGING HEART T-LIGHT HOLDER'), ('SCOTTIE DOG HOT WATER BOTTLE', "PAPER CHAIN KIT 50'S CHRISTMAS "), ('SCOTTIE DOG HOT WATER BOTTLE', 'RETRO SPOT TEA SET CERAMIC 11 PC '), ('SCOTTIE DOG HOT WATER BOTTLE', 'JUMBO BAG PINK VINTAGE PAISLEY'), ('SCOTTIE DOG HOT WATER BOTTLE', 'PLEASE ONE PERSON  METAL SIGN'), ('SCOTTIE DOG HOT WATER BOTTLE', 'PAPER CHAIN KIT RETRO SPOT'), ('SCOTTIE DOG HOT WATER BOTTLE', 'HOT WATER BOTTLE TEA AND SYMPATHY'), ('SCOTTIE DOG HOT WATER BOTTLE', 'ASSORTED COLOUR BIRD ORNAMENT'), ('SCOTTIE DOG HOT WATER BOTTLE', 'KINGS CHOICE SMALL TUBE MATCHES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CHOCOLATE HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'KINGS CHOICE CIGAR BOX MATCHES '), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOT HEART HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'JUMBO BAG RED WHITE SPOTTY '), ('SCOTTIE DOG HOT WATER BOTTLE', 'WHITE SKULL HOT WATER BOTTLE '), ('SCOTTIE DOG HOT WATER BOTTLE', 'FELTCRAFT DOLL MARIA'), ('SCOTTIE DOG HOT WATER BOTTLE', 'FELTCRAFT DOLL EMILY'), ('SCOTTIE DOG HOT WATER BOTTLE', 'GREY HEART HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CHICK GREY HOT WATER BOTTLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'PACK OF 72 RETRO SPOT CAKE CASES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'PINK 3 PIECE MINI DOTS CUTLERY SET'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CHARLOTTE BAG , PINK/WHITE SPOTS'), ('SCOTTIE DOG HOT WATER BOTTLE', '60 TEATIME FAIRY CAKE CASES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'WOODEN BOX ADVENT CALENDAR '), ('SCOTTIE DOG HOT WATER BOTTLE', "SET OF THREE 50'S GIFT WRAPS "), ('SCOTTIE DOG HOT WATER BOTTLE', 'FELTCRAFT DOLL ROSIE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'LARGE HEART MEASURING SPOONS'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CINAMMON SET OF 9 T-LIGHTS'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOTTY CUP'), ('SCOTTIE DOG HOT WATER BOTTLE', 'REX CASH+CARRY JUMBO SHOPPER'), ('SCOTTIE DOG HOT WATER BOTTLE', 'HEART FILIGREE DOVE  SMALL'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CREAM HEART CARD HOLDER'), ('SCOTTIE DOG HOT WATER BOTTLE', 'WOODEN FRAME ANTIQUE WHITE '), ('SCOTTIE DOG HOT WATER BOTTLE', 'JUMBO  BAG BAROQUE BLACK WHITE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'SET 12 RETRO WHITE CHALK STICKS'), ('SCOTTIE DOG HOT WATER BOTTLE', 'JUMBO BAG SCANDINAVIAN PAISLEY'), ('SCOTTIE DOG HOT WATER BOTTLE', 'TRADITIONAL CHRISTMAS RIBBONS'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOTTY OVEN GLOVE DOUBLE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'FAIRY CAKE CANDLES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'DOOR MAT BLACK FLOCK '), ('SCOTTIE DOG HOT WATER BOTTLE', 'COSY HOUR CIGAR BOX MATCHES '), ('SCOTTIE DOG HOT WATER BOTTLE', 'JUMBO STORAGE BAG SUKI'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CAMOUFLAGE LED TORCH'), ('SCOTTIE DOG HOT WATER BOTTLE', 'SET/3 RED GINGHAM ROSE STORAGE BOX'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOTTY CHARLOTTE BAG'), ('SCOTTIE DOG HOT WATER BOTTLE', '36 PENCILS TUBE RED SPOTTY'), ('SCOTTIE DOG HOT WATER BOTTLE', 'SMALL RETRO SPOT MUG IN BOX  WHITE'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RETRO SPOT TRADITIONAL TEAPOT '), ('SCOTTIE DOG HOT WATER BOTTLE', 'SET/20 RED SPOTTY PAPER NAPKINS '), ('SCOTTIE DOG HOT WATER BOTTLE', 'VINTAGE UNION JACK BUNTING'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED SPOTTY BISCUIT TIN'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RETRO SPOT SUGAR JAM BOWL'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RETRO SPOT CAKE STAND'), ('SCOTTIE DOG HOT WATER BOTTLE', '60 GOLD AND SILVER FAIRY CAKE CASES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'SET OF 72 RETRO SPOT PAPER  DOILIES'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CHARLOTTE BAG , SUKI DESIGN'), ('SCOTTIE DOG HOT WATER BOTTLE', 'RED GINGHAM ROSE JEWELLERY BOX'), ('SCOTTIE DOG HOT WATER BOTTLE', 'CH ...
# El tamaño del conjunto F2 es  1190
# El conjunto F3 es  []
# El tamaño del conjunto F3 es  0
